# %% [markdown]
# # Evaluating various pre-trained models on SimLex-999

# %% [markdown]
# In this file correlations between various pretrained models similarity and SimLex-999 similarity are calculated, also correlations between the models' similarity score and similarity attained from Estonian raters are calculated.
# <br>
# Lastly the SimLex-999 dataset is also filtered by POS group and the correlations with these filtered datasets are calculated.

# %% [markdown]
# ## Imports

# %%
from __future__ import print_function
import gensim
print(gensim.__version__) 
import pandas as pd
from scipy.stats import pearsonr, spearmanr, kendalltau, linregress
import matplotlib.pyplot as plt
import numpy as np
from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import KeyedVectors
from gensim.models.wrappers import FastText
import os
# Out:
# 3.7.0

# %% [markdown]
# ## Facebook research fastText vectors

# %% [markdown]
# Facebook research fastText vectors for English and Estonian were downloaded from https://github.com/facebookresearch/fastText/blob/master/docs/crawl-vectors.md
# These pre-trained vectors were trained using CBOW with position-weights, in dimension 300, character n-grams of length 5, window size 5 and 10 negaitves.
# Similarity between concepts are derived from the vectors. Used similarity measure is cosine similarity. This aquired similarities are compared with the SimLex-999 ones and correlation between them are found. Also similarity between different POS groups are found and also the results are compared with the SimLex-999.

# %%
# loading pretrained vectors
wiki_model_est = KeyedVectors.load_word2vec_format('wiki.et.vec')
wiki_model_eng = KeyedVectors.load_word2vec_format('wiki.en.vec')

# %%
# loading the translated Simlex-999 to dataframe
file_name = "SimLex-999-eng-est.xlsx"
data = pd.read_excel(file_name)
data.head()
# Out:
#   word 1       word 2   sõna 1         sõna 2 POS  SimLex999  conc(w1)  \
# 0    old          new     vana            uus   A       1.58      2.72
# 1  smart  intelligent     tark  intelligentne   A       9.20      1.75
# 2   hard    difficult     kõva          raske   A       8.77      3.76
# 3  happy     cheerful  õnnelik   rõõmsameelne   A       9.55      2.56
# 4   hard         easy     kõva         lihtne   A       0.95      3.76
#
#    conc(w2)  concQ  Assoc(USF)  SimAssoc333  SD(SimLex)  Average
# 0      2.81      2        7.25            1        0.41     0.00
# 1      2.46      1        7.11            1        0.67     9.00
# 2      2.21      2        5.94            1        1.19     1.50
# 3      2.34      1        5.85            1        2.18     9.25
# 4      2.07      2        5.82            1        0.93     0.00

# %% [markdown]
# ## All the methods used

# %%
def getSimilarityFromModel(model, data):
    # finds the similarity between concepts from the model, drops all the concept pairs, that are not represented in the model
    # returns 2 dataframes- one for the similarities and the other for missing pairs. 
    df = pd.DataFrame(columns=["word1", "word2","Sõna1", "Sõna2", "SimLex999", "SimFromModel", "POS", "simest"])
    missing = pd.DataFrame(columns=["word1", "word2", "Sõna 1", "Sõna 2"])
    for index, row in data.iterrows():
        word1 = row["sõna 1"].lower().strip()
        word2 = row["sõna 2"].lower().strip()
        eword1 = row["word 1"]
        eword2 = row["word 2"]
        simlex = row["SimLex999"]
        pos = row["POS"]
        try: 
            sim = model.similarity(word1, word2)
            df = df.append({"word1":eword1, "word2": eword2,"Sõna1":word1, "Sõna2":word2, "SimLex999":simlex,"simest":row["Average"], "SimFromModel":sim, "POS":pos}, ignore_index=True)
        except: 
            missing = missing.append({"word1":eword1, "word2": eword2, "Sõna 1":word1, "Sõna 2":word2}, ignore_index=True)
    return df, missing


def correlations(df):
    # Finds correlations between SimLex-999 and model
    # returns the correlations
    pearson = pearsonr(df.SimLex999, df.SimFromModel)
    spearman = spearmanr(df.SimLex999, df.SimFromModel)
    kendall = kendalltau(df.SimLex999, df.SimFromModel)
    
    pearsonEst = pearsonr(df.simest, df.SimFromModel)
    spearmanEst = spearmanr(df.simest, df.SimFromModel)
    kendallEst = kendalltau(df.simest, df.SimFromModel)
    return {"pearson":pearson, "spearman":spearman, "kendall": kendall, "pearsonEst":pearsonEst, "spearmanEst":spearmanEst, "kendallEst": kendallEst}


def transform(row):
    # scaales the similarity from the model into the 0-10 scale 
    return 10*(row["SimFromModel"] - minV)/(maxV-minV)

def printCorrelations(dic):
    # Prints the correlations
    print("Pearson correlation: " + str(dic["pearson"][0]))
    print("Spearman correlation: " + str(dic["spearman"][0]))
    print("Kendall tau correlation: " + str(dic["kendall"][0]))
    print("Pearson correlation between estsim and model: " + str(dic["pearsonEst"][0]))
    print("Spearman correlation between estsim and model: " + str(dic["spearmanEst"][0]))
    print("Kendall tau correlation between estsim and model: " + str(dic["kendallEst"][0]))

def evaluateModel(model, name, data):
    # uses all the other methods to evaluate the model and saves to an excel file
    p,m = getSimilarityFromModel(model, data)
    p["SimFromModel"] = p.apply(transform, axis=1)
    print(name)
    print("Missing pairs: "+ str(m.shape[0]))
    printCorrelations(correlations(p))
    writer = pd.ExcelWriter(name+'_similarity.xlsx', engine='xlsxwriter')
    p.to_excel(writer, sheet_name="similarities")
    m.to_excel(writer, sheet_name="missing pairs")


def evaluateModelsList(models):
    
    for model in models: 
        evaluateModel(model, )

# %%
minV, maxV = -1, 1
evaluateModel(wiki_model_est, "wiki_model_est_fastText", data)
# Out:
# wiki_model_est_fastText
# Missing pairs: 19
# Pearson correlation: 0.29742956551538074
# Spearman correlation: 0.3048684145507242
# Kendall tau correlation: 0.20820516039731474
# Pearson correlation between estsim and model: 0.3689550410571098
# Spearman correlation between estsim and model: 0.3820545254678176
# Kendall tau correlation between estsim and model: 0.2677731193935729

# %% [markdown]
# ## word2vec models
#
# Models were trained with word2vec software, on an Estonian Reference corpus.

# %%
# loading the models 
lemma_est_model_cbow100 = KeyedVectors.load_word2vec_format('lemmas.cbow.s100.w2v.bin', binary=True)
lemma_est_model_sg100 = KeyedVectors.load_word2vec_format('lemmas.sg.s100.w2v.bin', binary=True)
lemma_est_model_cbow200 = KeyedVectors.load_word2vec_format('lemmas.cbow.s200.w2v.bin', binary=True)
lemma_est_model_sg200 = KeyedVectors.load_word2vec_format('lemmas.sg.s200.w2v.bin', binary=True)
word_est_model_cbow100 = KeyedVectors.load_word2vec_format('words.cbow.s200.w2v.bin', binary=True)
word_est_model_sg100 = KeyedVectors.load_word2vec_format('words.sg.s100.w2v.bin', binary=True)
word_est_model_cbow200 = KeyedVectors.load_word2vec_format('words.cbow.s200.w2v.bin', binary=True)
word_est_model_sg200 = KeyedVectors.load_word2vec_format('words.sg.s200.w2v.bin', binary=True)

# %%
# evaluating and writing results to an excel file. 
evaluateModel(lemma_est_model_cbow100, "lemma_est_model_cbow100", data)
print()
evaluateModel(lemma_est_model_sg100, "lemma_est_model_sg100", data)
print()
evaluateModel(lemma_est_model_cbow200, "lemma_est_model_cbow200", data)
print()
evaluateModel(lemma_est_model_sg200, "lemma_est_model_sg200", data)
print()
evaluateModel(word_est_model_sg100, "word_est_model_sg100", data)
print()
evaluateModel(word_est_model_cbow200, "word_est_model_cbow200", data)
print()
evaluateModel(word_est_model_sg200, "word_est_model_sg200", data)
print()
evaluateModel(word_est_model_cbow100, "word_est_model_cbow100", data)
# Out:
# lemma_est_model_cbow100
# Missing pairs: 33
# Pearson correlation: 0.25817643949076735
# Spearman correlation: 0.2529187888277373
# Kendall tau correlation: 0.16941882690587085
# Pearson correlation between estsim and model: 0.36041696812729196
# Spearman correlation between estsim and model: 0.37671405198929303
# Kendall tau correlation between estsim and model: 0.2608281172339406
#
# lemma_est_model_sg100
# Missing pairs: 33
# Pearson correlation: 0.2832954780415281
# Spearman correlation: 0.27542236275746
# Kendall tau correlation: 0.18512203471798525
# Pearson correlation between estsim and model: 0.3957702397870942
# Spearman correlation between estsim and model: 0.4134090338274725
# Kendall tau correlation between estsim and model: 0.2872655994285016
#
# lemma_est_model_cbow200
# Missing pairs: 33
# Pearson correlation: 0.27786883210839214
# Spearman correlation: 0.27432792876156525
# Kendall tau correlation: 0.18484261820887288
# Pearson correlation between estsim and model: 0.3827605127946673
# Spearman correlation between estsim and model: 0.3995431844145371
# Kendall tau correlation between estsim and model: 0.27853323219015924
#
# lemma_est_model_sg200
# Missing pairs: 33
# Pearson correlation: 0.29715677955211367
# Spearman correlation: 0.2957948445970881
# Kendall tau correlation: 0.19895959999233404
# Pearson correlation between estsim and model: 0.414000922323149
# Spearman correlation between estsim and model: 0.4349576020690414
# Kendall tau correlation between estsim and model: 0.30341042654483624
#
# word_est_model_sg100
# Missing pairs: 8
# Pearson correlation: 0.2747853993363821
# Spearman correlation: 0.26754912499928063
# Kendall tau correlation: 0.181732158583464
# Pearson correlation between estsim and model: 0.3899149422239418
# Spearman correlation between estsim and model: 0.4090809216792182
# Kendall tau correlation between estsim and model: 0.29026480876148275
#
# word_est_model_cbow200
# Missing pairs: 8
# Pearson correlation: 0.2638029231897853
# Spearman correlation: 0.25851692295604023
# Kendall tau correlation: 0.1768345544175955
# Pearson correlation between estsim and model: 0.3648176603958761
# Spearman correlation between estsim and model: 0.38492678669196734
# Kendall tau correlation between estsim and model: 0.2727455161110441
#
# word_est_model_sg200
# Missing pairs: 8
# Pearson correlation: 0.2829874491469491
# Spearman correlation: 0.2764004314666725
# Kendall tau correlation: 0.18720162645510535
# Pearson correlation between estsim and model: 0.3985448148972329
# Spearman correlation between estsim and model: 0.41547576673496744
# Kendall tau correlation between estsim and model: 0.2947017555365998
#
# word_est_model_cbow100
# Missing pairs: 8
# Pearson correlation: 0.2638029231897853
# Spearman correlation: 0.25851692295604023
# Kendall tau correlation: 0.1768345544175955
# Pearson correlation between estsim and model: 0.3648176603958761
# Spearman correlation between estsim and model: 0.38492678669196734
# Kendall tau correlation between estsim and model: 0.2727455161110441

# %% [markdown]
# ## Pretrained word and multi-sense embeddings for Estonian

# %%
# evaluating all the models (only the word vectors, not sense vectors)
models = os.listdir("models")
for modelname in models: 
    model = KeyedVectors.load_word2vec_format("models/"+modelname+"/"+"ettenten.txt.word_vectors")
    evaluateModel(model, modelname, data)
# Out:
# cbow_100_5_10_20
# Missing pairs: 17
# Pearson correlation: 0.2954388567231574
# Spearman correlation: 0.29219959653986355
# Kendall tau correlation: 0.1969216189969967
# Pearson correlation between estsim and model: 0.3840266905346261
# Spearman correlation between estsim and model: 0.41335158930072824
# Kendall tau correlation between estsim and model: 0.28791074238552683
# cbow_150_15_10_20
# Missing pairs: 17
# Pearson correlation: 0.31061896457898386
# Spearman correlation: 0.318086510964076
# Kendall tau correlation: 0.21623585744990617
# Pearson correlation between estsim and model: 0.41190654903024576
# Spearman correlation between estsim and model: 0.44818150386039374
# Kendall tau correlation between estsim and model: 0.3148940453249254
# cbow_150_15_5_20
# Missing pairs: 15
# Pearson correlation: 0.31182441120328663
# Spearman correlation: 0.3193273770411882
# Kendall tau correlation: 0.21681421958919792
# Pearson correlation between estsim and model: 0.4111472245183176
# Spearman correlation between estsim and model: 0.44779639485721123
# Kendall tau correlation between estsim and model: 0.31499916829677904
# cbow_150_5_10_20
# Missing pairs: 17
# Pearson correlation: 0.29840301607625785
# Spearman correlation: 0.2982931324100423
# Kendall tau correlation: 0.20204240890342173
# Pearson correlation between estsim and model: 0.391556322622135
# Spearman correlation between estsim and model: 0.4231453741940345
# Kendall tau correlation between estsim and model: 0.29604634783432954
# cbow_150_5_10_5
# Missing pairs: 17
# Pearson correlation: 0.30281222877360825
# Spearman correlation: 0.3047386468466986
# Kendall tau correlation: 0.20584868247318527
# Pearson correlation between estsim and model: 0.39892218291561954
# Spearman correlation between estsim and model: 0.43141374169308333
# Kendall tau correlation between estsim and model: 0.30067048551271813
# cbow_150_5_5_20
# Missing pairs: 15
# Pearson correlation: 0.2974351287106514
# Spearman correlation: 0.2961334211776261
# Kendall tau correlation: 0.2003916304932731
# Pearson correlation between estsim and model: 0.3881093157322919
# Spearman correlation between estsim and model: 0.41887199517010276
# Kendall tau correlation between estsim and model: 0.29271907330325464
# cbow_300_10_10_5
# Missing pairs: 17
# Pearson correlation: 0.32021404432658657
# Spearman correlation: 0.3268292350481989
# Kendall tau correlation: 0.22193902801181417
# Pearson correlation between estsim and model: 0.42539120454662993
# Spearman correlation between estsim and model: 0.4599758899131411
# Kendall tau correlation between estsim and model: 0.32343579644355913
# cbow_300_15_10_20
# Missing pairs: 17
# Pearson correlation: 0.32182266660352926
# Spearman correlation: 0.3321157565698232
# Kendall tau correlation: 0.22649823657188067
# Pearson correlation between estsim and model: 0.42700225254439306
# Spearman correlation between estsim and model: 0.46270394377036794
# Kendall tau correlation between estsim and model: 0.326591886752871
# cbow_300_15_10_5
# Missing pairs: 17
# Pearson correlation: 0.32076373515938555
# Spearman correlation: 0.3308487135657892
# Kendall tau correlation: 0.22543331194471186
# Pearson correlation between estsim and model: 0.4289355385498315
# Spearman correlation between estsim and model: 0.46663014344604975
# Kendall tau correlation between estsim and model: 0.32850838663238613
# cbow_300_1_10_20
# Missing pairs: 17
# Pearson correlation: 0.34322059921585474
# Spearman correlation: 0.3535662368582634
# Kendall tau correlation: 0.2408248006967612
# Pearson correlation between estsim and model: 0.4618324699560957
# Spearman correlation between estsim and model: 0.4918595801362419
# Kendall tau correlation between estsim and model: 0.3470049373459406
# cbow_300_30_10_20
# Missing pairs: 17
# Pearson correlation: 0.32574045042262334
# Spearman correlation: 0.34263076062783404
# Kendall tau correlation: 0.23401094702761072
# Pearson correlation between estsim and model: 0.4339863247091543
# Spearman correlation between estsim and model: 0.4731562613850525
# Kendall tau correlation between estsim and model: 0.33531132660205576
# cbow_300_5_10_10
# Missing pairs: 17
# Pearson correlation: 0.31421519198036496
# Spearman correlation: 0.316912019865868
# Kendall tau correlation: 0.2153331674339076
# Pearson correlation between estsim and model: 0.41943800904604106
# Spearman correlation between estsim and model: 0.4493381048743697
# Kendall tau correlation between estsim and model: 0.31634093927369844
# cbow_300_5_10_20
# Missing pairs: 17
# Pearson correlation: 0.30676666019230175
# Spearman correlation: 0.3094223549385716
# Kendall tau correlation: 0.2106158841244957
# Pearson correlation between estsim and model: 0.4086167789674953
# Spearman correlation between estsim and model: 0.4391056385593569
# Kendall tau correlation between estsim and model: 0.30918262184292666
# cbow_300_5_10_5
# Missing pairs: 17
# Pearson correlation: 0.31439054418476275
# Spearman correlation: 0.31952288080670055
# Kendall tau correlation: 0.21736733986627305
# Pearson correlation between estsim and model: 0.4168505174409361
# Spearman correlation between estsim and model: 0.44998718060285053
# Kendall tau correlation between estsim and model: 0.3159771004444748
# cbow_300_5_15_5
# Missing pairs: 19
# Pearson correlation: 0.31629597809450416
# Spearman correlation: 0.31893727224243745
# Kendall tau correlation: 0.21642276775644934
# Pearson correlation between estsim and model: 0.4200230039235607
# Spearman correlation between estsim and model: 0.4505302694962672
# Kendall tau correlation between estsim and model: 0.31611164316605783
# cbow_300_5_2_20
# Missing pairs: 8
# Pearson correlation: 0.30938469902135884
# Spearman correlation: 0.3118033492324987
# Kendall tau correlation: 0.21169227901655843
# Pearson correlation between estsim and model: 0.4101791672349
# Spearman correlation between estsim and model: 0.4392485273287423
# Kendall tau correlation between estsim and model: 0.30909007734047506
# cbow_300_5_5_20
# Missing pairs: 15
# Pearson correlation: 0.30962249408444087
# Spearman correlation: 0.31162885409993724
# Kendall tau correlation: 0.21176812637052073
# Pearson correlation between estsim and model: 0.40820420410084485
# Spearman correlation between estsim and model: 0.43907514869320885
# Kendall tau correlation between estsim and model: 0.309163704687469
# cbow_300_5_5_5
# Missing pairs: 15
# Pearson correlation: 0.31125808055215287
# Spearman correlation: 0.3149858025169181
# Kendall tau correlation: 0.21360758892314197
# Pearson correlation between estsim and model: 0.4109374039873602
# Spearman correlation between estsim and model: 0.4439328712133395
# Kendall tau correlation between estsim and model: 0.31128722357490024
# cbow_450_5_10_5
# Missing pairs: 17
# Pearson correlation: 0.32291967509024855
# Spearman correlation: 0.32895177016018184
# Kendall tau correlation: 0.22347401702519423
# Pearson correlation between estsim and model: 0.4247036953156023
# Spearman correlation between estsim and model: 0.4565988998672347
# Kendall tau correlation between estsim and model: 0.3208804632708722
# cbow_750_5_10_20
# Missing pairs: 17
# Pearson correlation: 0.31425334415499034
# Spearman correlation: 0.31672260114712575
# Kendall tau correlation: 0.21591554808939056
# Pearson correlation between estsim and model: 0.4146819357303274
# Spearman correlation between estsim and model: 0.44023825775566344
# Kendall tau correlation between estsim and model: 0.3100245279710139
# skip_150_5_10_5
# Missing pairs: 17
# Pearson correlation: 0.3066131044860912
# Spearman correlation: 0.30971638322568423
# Kendall tau correlation: 0.20935544599155761
# Pearson correlation between estsim and model: 0.41030230243135596
# Spearman correlation between estsim and model: 0.4442929735883456
# Kendall tau correlation between estsim and model: 0.3116448799662772
# skip_300_10_10_5
# Missing pairs: 17
# Pearson correlation: 0.298767438776021
# Spearman correlation: 0.3071211978797728
# Kendall tau correlation: 0.20861083072490444
# Pearson correlation between estsim and model: 0.40265365546993886
# Spearman correlation between estsim and model: 0.4395175790809592
# Kendall tau correlation between estsim and model: 0.3101218337044109
# skip_300_15_10_5
# Missing pairs: 17
# Pearson correlation: 0.2862594312945379
# Spearman correlation: 0.2938624007946537
# Kendall tau correlation: 0.19883099557461575
# Pearson correlation between estsim and model: 0.3838537354125905
# Spearman correlation between estsim and model: 0.41857051106655735
# Kendall tau correlation between estsim and model: 0.2942440764244543
# skip_300_5_10_10
# Missing pairs: 17
# Pearson correlation: 0.3110974350109412
# Spearman correlation: 0.31882591876541594
# Kendall tau correlation: 0.21680575851991446
# Pearson correlation between estsim and model: 0.42253872274562315
# Spearman correlation between estsim and model: 0.4573052439987142
# Kendall tau correlation between estsim and model: 0.323469641916045
# skip_300_5_10_20
# Missing pairs: 17
# Pearson correlation: 0.3168856380502366
# Spearman correlation: 0.3267330905545313
# Kendall tau correlation: 0.2219764667682381
# Pearson correlation between estsim and model: 0.42881444843548855
# Spearman correlation between estsim and model: 0.46581185033761563
# Kendall tau correlation between estsim and model: 0.329811437323094
# skip_300_5_10_5
# Missing pairs: 17
# Pearson correlation: 0.3130262580733771
# Spearman correlation: 0.32019110848138554
# Kendall tau correlation: 0.2172799827679506
# Pearson correlation between estsim and model: 0.4261855994844989
# Spearman correlation between estsim and model: 0.46125817188906376
# Kendall tau correlation between estsim and model: 0.32567382831169045
# skip_300_5_15_5
# Missing pairs: 19
# Pearson correlation: 0.3148014108491682
# Spearman correlation: 0.3226769337082471
# Kendall tau correlation: 0.21876181860020177
# Pearson correlation between estsim and model: 0.4269621076275724
# Spearman correlation between estsim and model: 0.4623424785194456
# Kendall tau correlation between estsim and model: 0.3259626530498459
# skip_300_5_5_5
# Missing pairs: 15
# Pearson correlation: 0.3119691247327846
# Spearman correlation: 0.3193070673565319
# Kendall tau correlation: 0.21656978650225048
# Pearson correlation between estsim and model: 0.4242590342013266
# Spearman correlation between estsim and model: 0.45725913420810105
# Kendall tau correlation between estsim and model: 0.32146241824384153
# skip_450_5_10_5
# Missing pairs: 17
# Pearson correlation: 0.3151249737589864
# Spearman correlation: 0.3256705019146509
# Kendall tau correlation: 0.2208241850427468
# Pearson correlation between estsim and model: 0.43034396660272806
# Spearman correlation between estsim and model: 0.46460200220400594
# Kendall tau correlation between estsim and model: 0.32756494408684117

# %% [markdown]
# ## Correlation, when filtered by POS

# %% [markdown]
# Dataset is now filtered by the POS of the concepts and after that the correlation is find. Reason for this is to find if models can find similarity from certain POS group better.

# %%
# filtering the data set 
dataA = data[data['POS']=='A']
dataN = data[data['POS'] =='N']
dataV = data[data['POS']=='V']

# %%
dataV.head()
# Out:
#      word 1       word 2   sõna 1      sõna 2 POS  SimLex999  conc(w1)  \
# 777      go         come   minema      tulema   V       2.42      3.15
# 778    take        steal    võtma   varastama   V       6.18      3.06
# 779  listen         hear  kuulama      kuulma   V       8.17      3.47
# 780   think  rationalize  mõtlema  põhjendama   V       8.25      2.41
# 781   occur       happen  ilmnema     juhtuma   V       9.32      1.84
#
#      conc(w2)  concQ  Assoc(USF)  SimAssoc333  SD(SimLex)  Average
# 777      2.72      2        5.75            1        1.51     2.25
# 778      3.84      2        3.28            1        1.69     6.00
# 779      3.66      2        3.22            1        1.72     6.00
# 780      1.52      1        3.17            1        1.13     3.25
# 781      1.78      1        2.87            1        1.34     7.00

# %%
evaluateModel(wiki_model_est, "wiki_model_est_fastText_A", dataA)
print()
evaluateModel(wiki_model_est, "wiki_model_est_fastText_N", dataN)
print()
evaluateModel(wiki_model_est, "wiki_model_est_fastText_V", dataV)
# Out:
# wiki_model_est_fastText_A
# Missing pairs: 0
# Pearson correlation: 0.19942352221591134
# Spearman correlation: 0.22603745056542013
# Kendall tau correlation: 0.1533789947383818
# Pearson correlation between estsim and model: 0.2697437314615472
# Spearman correlation between estsim and model: 0.254643514221926
# Kendall tau correlation between estsim and model: 0.18774964451071988
#
# wiki_model_est_fastText_N
# Missing pairs: 8
# Pearson correlation: 0.37321923634180215
# Spearman correlation: 0.38413798711574537
# Kendall tau correlation: 0.2630880942449072
# Pearson correlation between estsim and model: 0.4874698456400136
# Spearman correlation between estsim and model: 0.5219775714034443
# Kendall tau correlation between estsim and model: 0.3720482526193223
#
# wiki_model_est_fastText_V
# Missing pairs: 11
# Pearson correlation: 0.1307391578570072
# Spearman correlation: 0.1491977079888748
# Kendall tau correlation: 0.10420445592542614
# Pearson correlation between estsim and model: 0.24017698108769425
# Spearman correlation between estsim and model: 0.23454275685505668
# Kendall tau correlation between estsim and model: 0.16669325961395393

# %%
# evaluating and writing results to an excel file. 
evaluateModel(lemma_est_model_cbow100, "lemma_est_model_cbow100", dataA)
evaluateModel(lemma_est_model_cbow100, "lemma_est_model_cbow100", dataN)
evaluateModel(lemma_est_model_cbow100, "lemma_est_model_cbow100", dataV)
print()
evaluateModel(lemma_est_model_sg100, "lemma_est_model_sg100", dataA)
evaluateModel(lemma_est_model_sg100, "lemma_est_model_sg100", dataN)
evaluateModel(lemma_est_model_sg100, "lemma_est_model_sg100", dataV)
print()
evaluateModel(lemma_est_model_cbow200, "lemma_est_model_cbow200", dataA)
evaluateModel(lemma_est_model_cbow200, "lemma_est_model_cbow200", dataN)
evaluateModel(lemma_est_model_cbow200, "lemma_est_model_cbow200", dataV)
print()
evaluateModel(lemma_est_model_sg200, "lemma_est_model_sg200", dataA)
evaluateModel(lemma_est_model_sg200, "lemma_est_model_sg200", dataN)
evaluateModel(lemma_est_model_sg200, "lemma_est_model_sg200", dataV)
print()
evaluateModel(word_est_model_sg100, "word_est_model_sg100", dataA)
evaluateModel(word_est_model_sg100, "word_est_model_sg100", dataN)
evaluateModel(word_est_model_sg100, "word_est_model_sg100", dataV)
print()
evaluateModel(word_est_model_cbow200, "word_est_model_cbow200", dataA)
evaluateModel(word_est_model_cbow200, "word_est_model_cbow200", dataN)
evaluateModel(word_est_model_cbow200, "word_est_model_cbow200", dataV)

print()
evaluateModel(word_est_model_sg200, "word_est_model_sg200", dataA)
evaluateModel(word_est_model_sg200, "word_est_model_sg200", dataN)
evaluateModel(word_est_model_sg200, "word_est_model_sg200", dataV)
print()
evaluateModel(word_est_model_cbow100, "word_est_model_cbow100", dataA)
evaluateModel(word_est_model_cbow100, "word_est_model_cbow100", dataN)
evaluateModel(word_est_model_cbow100, "word_est_model_cbow100", dataV)
# Out:
# lemma_est_model_cbow100
# Missing pairs: 0
# Pearson correlation: 0.18443311245855473
# Spearman correlation: 0.21838505534104458
# Kendall tau correlation: 0.14943777859949403
# Pearson correlation between estsim and model: 0.24049162777885355
# Spearman correlation between estsim and model: 0.22409274752533495
# Kendall tau correlation between estsim and model: 0.16085531646657325
# lemma_est_model_cbow100
# Missing pairs: 30
# Pearson correlation: 0.3194940528183155
# Spearman correlation: 0.29748311980635556
# Kendall tau correlation: 0.1995324694355773
# Pearson correlation between estsim and model: 0.4058688426144968
# Spearman correlation between estsim and model: 0.4230691662466578
# Kendall tau correlation between estsim and model: 0.2931383546625192
# lemma_est_model_cbow100
# Missing pairs: 3
# Pearson correlation: 0.16739164125731498
# Spearman correlation: 0.15349946006296128
# Kendall tau correlation: 0.1045632192414878
# Pearson correlation between estsim and model: 0.3035986711637522
# Spearman correlation between estsim and model: 0.2575699155983341
# Kendall tau correlation between estsim and model: 0.17935909488265064
#
# lemma_est_model_sg100
# Missing pairs: 0
# Pearson correlation: 0.2848638331940325
# Spearman correlation: 0.3024824216658044
# Kendall tau correlation: 0.21216880214345746
# Pearson correlation between estsim and model: 0.3606418668586608
# Spearman correlation between estsim and model: 0.33654698065526156
# Kendall tau correlation between estsim and model: 0.24834699124310092
# lemma_est_model_sg100
# Missing pairs: 30
# Pearson correlation: 0.3382997905065013
# Spearman correlation: 0.3119104967502507
# Kendall tau correlation: 0.21027053274806862
# Pearson correlation between estsim and model: 0.43480955467351357
# Spearman correlation between estsim and model: 0.4516247166717535
# Kendall tau correlation between estsim and model: 0.31479520024041224
# lemma_est_model_sg100
# Missing pairs: 3
# Pearson correlation: 0.17652773096111962
# Spearman correlation: 0.15440434877596493
# Kendall tau correlation: 0.10347227072612719
# Pearson correlation between estsim and model: 0.31714883016929574
# Spearman correlation between estsim and model: 0.2727583727376928
# Kendall tau correlation between estsim and model: 0.18816093644051948
#
# lemma_est_model_cbow200
# Missing pairs: 0
# Pearson correlation: 0.19992475314985655
# Spearman correlation: 0.226555215838629
# Kendall tau correlation: 0.15502116812958502
# Pearson correlation between estsim and model: 0.26077517265661454
# Spearman correlation between estsim and model: 0.243090814746066
# Kendall tau correlation between estsim and model: 0.1788983466734058
# lemma_est_model_cbow200
# Missing pairs: 30
# Pearson correlation: 0.34332295342739794
# Spearman correlation: 0.3262705158790595
# Kendall tau correlation: 0.22025435131772322
# Pearson correlation between estsim and model: 0.43271464105049345
# Spearman correlation between estsim and model: 0.4525933894628698
# Kendall tau correlation between estsim and model: 0.3155107125884952
# lemma_est_model_cbow200
# Missing pairs: 3
# Pearson correlation: 0.18198416785116842
# Spearman correlation: 0.17086486858435374
# Kendall tau correlation: 0.11555662351166028
# Pearson correlation between estsim and model: 0.3187885678289319
# Spearman correlation between estsim and model: 0.2813129888388341
# Kendall tau correlation between estsim and model: 0.19679019286980265
#
# lemma_est_model_sg200
# Missing pairs: 0
# Pearson correlation: 0.27116262381184203
# Spearman correlation: 0.2680203161083243
# Kendall tau correlation: 0.18884993998837157
# Pearson correlation between estsim and model: 0.36642182261297657
# Spearman correlation between estsim and model: 0.3296056342422879
# Kendall tau correlation between estsim and model: 0.2425596041956263
# lemma_est_model_sg200
# Missing pairs: 30
# Pearson correlation: 0.3521966302579745
# Spearman correlation: 0.3375963313243375
# Kendall tau correlation: 0.22778687447315846
# Pearson correlation between estsim and model: 0.45202400711067087
# Spearman correlation between estsim and model: 0.4759278129187053
# Kendall tau correlation between estsim and model: 0.33261246547154993
# lemma_est_model_sg200
# Missing pairs: 3
# Pearson correlation: 0.23136123338121128
# Spearman correlation: 0.20692388402217246
# Kendall tau correlation: 0.13955749084959407
# Pearson correlation between estsim and model: 0.3590500110471771
# Spearman correlation between estsim and model: 0.3221549736991891
# Kendall tau correlation between estsim and model: 0.2273377606294651
#
# word_est_model_sg100
# Missing pairs: 0
# Pearson correlation: 0.16485632049672588
# Spearman correlation: 0.16601616944487382
# Kendall tau correlation: 0.11133935592357906
# Pearson correlation between estsim and model: 0.2645501193716486
# Spearman correlation between estsim and model: 0.22802322966618435
# Kendall tau correlation between estsim and model: 0.14757836971060212
# word_est_model_sg100
# Missing pairs: 3
# Pearson correlation: 0.32434873819667775
# Spearman correlation: 0.310251853908805
# Kendall tau correlation: 0.2096745398362204
# Pearson correlation between estsim and model: 0.4357399212351378
# Spearman correlation between estsim and model: 0.4644295118961637
# Kendall tau correlation between estsim and model: 0.3289450770812942
# word_est_model_sg100
# Missing pairs: 5
# Pearson correlation: 0.19163570215431416
# Spearman correlation: 0.21468906490364315
# Kendall tau correlation: 0.14527210752807293
# Pearson correlation between estsim and model: 0.3561674540319958
# Spearman correlation between estsim and model: 0.3537611920848015
# Kendall tau correlation between estsim and model: 0.2503523147464088
#
# word_est_model_cbow200
# Missing pairs: 0
# Pearson correlation: 0.1439477901668032
# Spearman correlation: 0.1511545509672592
# Kendall tau correlation: 0.11035405188885712
# Pearson correlation between estsim and model: 0.22637880809199007
# Spearman correlation between estsim and model: 0.19967424036682957
# Kendall tau correlation between estsim and model: 0.14179098266312753
# word_est_model_cbow200
# Missing pairs: 3
# Pearson correlation: 0.3141805092416015
# Spearman correlation: 0.30517746550143054
# Kendall tau correlation: 0.2074460971269235
# Pearson correlation between estsim and model: 0.4224196845925625
# Spearman correlation between estsim and model: 0.454271400468344
# Kendall tau correlation between estsim and model: 0.32011059987923507
# word_est_model_cbow200
# Missing pairs: 5
# Pearson correlation: 0.17424211816235866
# Spearman correlation: 0.21385698795529956
# Kendall tau correlation: 0.14364800041243103
# Pearson correlation between estsim and model: 0.3408412744945516
# Spearman correlation between estsim and model: 0.36358405330074195
# Kendall tau correlation between estsim and model: 0.2571174062485928
#
# word_est_model_sg200
# Missing pairs: 0
# Pearson correlation: 0.18956515234592944
# Spearman correlation: 0.17871019432108848
# Kendall tau correlation: 0.12283456966200168
# Pearson correlation between estsim and model: 0.29489215062852664
# Spearman correlation between estsim and model: 0.2478038563232825
# Kendall tau correlation between estsim and model: 0.1731109596259312
# word_est_model_sg200
# Missing pairs: 3
# Pearson correlation: 0.32439783742909
# Spearman correlation: 0.3174950477968959
# Kendall tau correlation: 0.2138026386255736
# Pearson correlation between estsim and model: 0.436896310260104
# Spearman correlation between estsim and model: 0.4688683905083236
# Kendall tau correlation between estsim and model: 0.33119081603391853
# word_est_model_sg200
# Missing pairs: 5
# Pearson correlation: 0.22393057388183113
# Spearman correlation: 0.23209045395601624
# Kendall tau correlation: 0.15484579157817246
# Pearson correlation between estsim and model: 0.3804699090665296
# Spearman correlation between estsim and model: 0.3666406962383557
# Kendall tau correlation between estsim and model: 0.25896243120373397
#
# word_est_model_cbow100
# Missing pairs: 0
# Pearson correlation: 0.1439477901668032
# Spearman correlation: 0.1511545509672592
# Kendall tau correlation: 0.11035405188885712
# Pearson correlation between estsim and model: 0.22637880809199007
# Spearman correlation between estsim and model: 0.19967424036682957
# Kendall tau correlation between estsim and model: 0.14179098266312753
# word_est_model_cbow100
# Missing pairs: 3
# Pearson correlation: 0.3141805092416015
# Spearman correlation: 0.30517746550143054
# Kendall tau correlation: 0.2074460971269235
# Pearson correlation between estsim and model: 0.4224196845925625
# Spearman correlation between estsim and model: 0.454271400468344
# Kendall tau correlation between estsim and model: 0.32011059987923507
# word_est_model_cbow100
# Missing pairs: 5
# Pearson correlation: 0.17424211816235866
# Spearman correlation: 0.21385698795529956
# Kendall tau correlation: 0.14364800041243103
# Pearson correlation between estsim and model: 0.3408412744945516
# Spearman correlation between estsim and model: 0.36358405330074195
# Kendall tau correlation between estsim and model: 0.2571174062485928

# %%
models = os.listdir("models")
for modelname in models: 
    model = KeyedVectors.load_word2vec_format("models/"+modelname+"/"+"ettenten.txt.word_vectors")
    evaluateModel(model, modelname+"_A", dataA)
    evaluateModel(model, modelname+"_N", dataN)
    evaluateModel(model, modelname+"_V", dataV)
# Out:
# cbow_100_5_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.2458993547683711
# Spearman correlation: 0.2841368571972757
# Kendall tau correlation: 0.21085506343049487
# Pearson correlation between estsim and model: 0.33209757374474047
# Spearman correlation between estsim and model: 0.32162087524749144
# Kendall tau correlation between estsim and model: 0.24358090779223948
# cbow_100_5_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.38007774709674663
# Spearman correlation: 0.35037217788763536
# Kendall tau correlation: 0.23678029627363983
# Pearson correlation between estsim and model: 0.43769389371920187
# Spearman correlation between estsim and model: 0.4593966802542283
# Kendall tau correlation between estsim and model: 0.3208255438811138
# cbow_100_5_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.17649384488397046
# Spearman correlation: 0.1652504454332173
# Kendall tau correlation: 0.11371040294720386
# Pearson correlation between estsim and model: 0.28681201797601324
# Spearman correlation between estsim and model: 0.25486534963659924
# Kendall tau correlation between estsim and model: 0.17927280231835782
# cbow_150_15_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.2768679561615357
# Spearman correlation: 0.30497471552328453
# Kendall tau correlation: 0.22891897073373044
# Pearson correlation between estsim and model: 0.3650232041340741
# Spearman correlation between estsim and model: 0.35084527001803656
# Kendall tau correlation between estsim and model: 0.2602621998702545
# cbow_150_15_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.3899312712388798
# Spearman correlation: 0.37622644476552963
# Kendall tau correlation: 0.25591272215157446
# Pearson correlation between estsim and model: 0.47209133676041065
# Spearman correlation between estsim and model: 0.502751081103163
# Kendall tau correlation between estsim and model: 0.3541270424923773
# cbow_150_15_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.19773036020747503
# Spearman correlation: 0.1889877786420106
# Kendall tau correlation: 0.13024246891074567
# Pearson correlation between estsim and model: 0.29628015446932215
# Spearman correlation between estsim and model: 0.2670493705581309
# Kendall tau correlation between estsim and model: 0.18885127695486215
# cbow_150_15_5_20_A
# Missing pairs: 0
# Pearson correlation: 0.28770472597374597
# Spearman correlation: 0.3167472937268393
# Kendall tau correlation: 0.23351705622909943
# Pearson correlation between estsim and model: 0.38041238632438135
# Spearman correlation between estsim and model: 0.364993237229193
# Kendall tau correlation between estsim and model: 0.272177408497408
# cbow_150_15_5_20_N
# Missing pairs: 14
# Pearson correlation: 0.3930947578169811
# Spearman correlation: 0.3795408806594286
# Kendall tau correlation: 0.25847189659033076
# Pearson correlation between estsim and model: 0.47441564494556354
# Spearman correlation between estsim and model: 0.5046953432820884
# Kendall tau correlation between estsim and model: 0.3562185800023904
# cbow_150_15_5_20_V
# Missing pairs: 1
# Pearson correlation: 0.19232789535319333
# Spearman correlation: 0.18490470387520697
# Kendall tau correlation: 0.12693914606900245
# Pearson correlation between estsim and model: 0.28158200105609854
# Spearman correlation between estsim and model: 0.2570531802776351
# Kendall tau correlation between estsim and model: 0.18258035063592934
# cbow_150_5_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.2554308587613119
# Spearman correlation: 0.28138129286189284
# Kendall tau correlation: 0.20625697793512582
# Pearson correlation between estsim and model: 0.3473891857386023
# Spearman correlation between estsim and model: 0.326988260308224
# Kendall tau correlation between estsim and model: 0.2490278603075097
# cbow_150_5_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.3801462274732314
# Spearman correlation: 0.3598731494691395
# Kendall tau correlation: 0.24412729890593654
# Pearson correlation between estsim and model: 0.4454255912030573
# Spearman correlation between estsim and model: 0.4733838315578578
# Kendall tau correlation between estsim and model: 0.33209873917590915
# cbow_150_5_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.19160596445419634
# Spearman correlation: 0.17394571759270525
# Kendall tau correlation: 0.11882946905774217
# Pearson correlation between estsim and model: 0.2935592952972918
# Spearman correlation between estsim and model: 0.2634904897176628
# Kendall tau correlation between estsim and model: 0.1848818189973919
# cbow_150_5_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.26374074640597683
# Spearman correlation: 0.28019218787003175
# Kendall tau correlation: 0.20362950050920067
# Pearson correlation between estsim and model: 0.351489820920907
# Spearman correlation between estsim and model: 0.3326828171107144
# Kendall tau correlation between estsim and model: 0.25175133656514476
# cbow_150_5_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.3874856618653213
# Spearman correlation: 0.36862054988401527
# Kendall tau correlation: 0.25021832293913887
# Pearson correlation between estsim and model: 0.45426779065189204
# Spearman correlation between estsim and model: 0.48063545905904714
# Kendall tau correlation between estsim and model: 0.33634897365726596
# cbow_150_5_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.20569949550834923
# Spearman correlation: 0.1825490155837629
# Kendall tau correlation: 0.1244520498676777
# Pearson correlation between estsim and model: 0.3179714527569504
# Spearman correlation between estsim and model: 0.27422274871103836
# Kendall tau correlation between estsim and model: 0.19126746875506143
# cbow_150_5_5_20_A
# Missing pairs: 0
# Pearson correlation: 0.26491863066173976
# Spearman correlation: 0.29136363181570835
# Kendall tau correlation: 0.21282567149993872
# Pearson correlation between estsim and model: 0.34828770887507404
# Spearman correlation between estsim and model: 0.32968963779760413
# Kendall tau correlation between estsim and model: 0.25209177109734915
# cbow_150_5_5_20_N
# Missing pairs: 14
# Pearson correlation: 0.37934118557954294
# Spearman correlation: 0.3582020226030702
# Kendall tau correlation: 0.24307907616533894
# Pearson correlation between estsim and model: 0.44626326436101826
# Spearman correlation between estsim and model: 0.4736113089543423
# Kendall tau correlation between estsim and model: 0.3317821302867787
# cbow_150_5_5_20_V
# Missing pairs: 1
# Pearson correlation: 0.1860789891688428
# Spearman correlation: 0.1674328329977802
# Kendall tau correlation: 0.11474375910489187
# Pearson correlation between estsim and model: 0.2784753546360368
# Spearman correlation between estsim and model: 0.24586585793384674
# Kendall tau correlation between estsim and model: 0.1733475702047921
# cbow_300_10_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.3147364849926018
# Spearman correlation: 0.3281688446265236
# Kendall tau correlation: 0.24369853125455948
# Pearson correlation between estsim and model: 0.41089513680256023
# Spearman correlation between estsim and model: 0.37638677207392746
# Kendall tau correlation between estsim and model: 0.28273087899574406
# cbow_300_10_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.406998333896257
# Spearman correlation: 0.3961061110813945
# Kendall tau correlation: 0.27006845087369885
# Pearson correlation between estsim and model: 0.4877853496139239
# Spearman correlation between estsim and model: 0.51888695988513
# Kendall tau correlation between estsim and model: 0.3658127887639183
# cbow_300_10_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.18772511667972158
# Spearman correlation: 0.16486541071568925
# Kendall tau correlation: 0.1122837779655784
# Pearson correlation between estsim and model: 0.3005730558882298
# Spearman correlation between estsim and model: 0.2593634034779836
# Kendall tau correlation between estsim and model: 0.18315596771153525
# cbow_300_15_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.29863245511919195
# Spearman correlation: 0.3166814761073636
# Kendall tau correlation: 0.23548766429854337
# Pearson correlation between estsim and model: 0.3859693659119718
# Spearman correlation between estsim and model: 0.3574019685724569
# Kendall tau correlation between estsim and model: 0.2684326286431598
# cbow_300_15_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.4004914753713085
# Spearman correlation: 0.39484742425745684
# Kendall tau correlation: 0.2690107846849878
# Pearson correlation between estsim and model: 0.48944378120419735
# Spearman correlation between estsim and model: 0.5242990497508506
# Kendall tau correlation between estsim and model: 0.37073461785858214
# cbow_300_15_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.19058226957051186
# Spearman correlation: 0.17811597491904793
# Kendall tau correlation: 0.12378069693514811
# Pearson correlation between estsim and model: 0.2917883355674789
# Spearman correlation between estsim and model: 0.2620530619317673
# Kendall tau correlation between estsim and model: 0.1844503561759277
# cbow_300_15_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.31263485752725756
# Spearman correlation: 0.32845405431091834
# Kendall tau correlation: 0.24337009657631883
# Pearson correlation between estsim and model: 0.4026341302953911
# Spearman correlation between estsim and model: 0.3787211866637683
# Kendall tau correlation between estsim and model: 0.28409261712456163
# cbow_300_15_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.4040741430822529
# Spearman correlation: 0.3988170622464197
# Kendall tau correlation: 0.272797607378498
# Pearson correlation between estsim and model: 0.49365370489605653
# Spearman correlation between estsim and model: 0.5281146807993309
# Kendall tau correlation between estsim and model: 0.37320992371905637
# cbow_300_15_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.19491167195106343
# Spearman correlation: 0.18356758665401893
# Kendall tau correlation: 0.12696962336466378
# Pearson correlation between estsim and model: 0.30003100249981457
# Spearman correlation between estsim and model: 0.2711460684162177
# Kendall tau correlation between estsim and model: 0.19178522414081842
# cbow_300_1_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.32014185073239254
# Spearman correlation: 0.2999945156496227
# Kendall tau correlation: 0.21282567149993872
# Pearson correlation between estsim and model: 0.4469937461673394
# Spearman correlation between estsim and model: 0.39077348623177227
# Kendall tau correlation between estsim and model: 0.2926034804296713
# cbow_300_1_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.39804625013015893
# Spearman correlation: 0.4056412650493423
# Kendall tau correlation: 0.27607448387387973
# Pearson correlation between estsim and model: 0.4928491250184036
# Spearman correlation between estsim and model: 0.5342745121394166
# Kendall tau correlation between estsim and model: 0.3773066508602288
# cbow_300_1_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.2905605198616277
# Spearman correlation: 0.28199194350510226
# Kendall tau correlation: 0.1949441077832875
# Pearson correlation between estsim and model: 0.41161190196558756
# Spearman correlation between estsim and model: 0.3777221362210394
# Kendall tau correlation between estsim and model: 0.2639258078896257
# cbow_300_30_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.2931366195833431
# Spearman correlation: 0.3150974653986482
# Kendall tau correlation: 0.23483079494206205
# Pearson correlation between estsim and model: 0.3816422861509254
# Spearman correlation between estsim and model: 0.3508187425795156
# Kendall tau correlation between estsim and model: 0.2691134977075686
# cbow_300_30_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.4034658989724052
# Spearman correlation: 0.4049865175648644
# Kendall tau correlation: 0.27630112662860357
# Pearson correlation between estsim and model: 0.5007649592078418
# Spearman correlation between estsim and model: 0.5403318724747419
# Kendall tau correlation between estsim and model: 0.3835524807639835
# cbow_300_30_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.19081874193473378
# Spearman correlation: 0.1835904373790948
# Kendall tau correlation: 0.12604651308243556
# Pearson correlation between estsim and model: 0.2838177547314452
# Spearman correlation between estsim and model: 0.25279607285985534
# Kendall tau correlation between estsim and model: 0.17987685026840763
# cbow_300_5_10_10_A
# Missing pairs: 0
# Pearson correlation: 0.3041720565724878
# Spearman correlation: 0.3038426524683024
# Kendall tau correlation: 0.21906593038651104
# Pearson correlation between estsim and model: 0.39553790219586565
# Spearman correlation between estsim and model: 0.3484666430306609
# Kendall tau correlation between estsim and model: 0.2650282833211159
# cbow_300_5_10_10_N
# Missing pairs: 14
# Pearson correlation: 0.3975383765164204
# Spearman correlation: 0.38536913990900734
# Kendall tau correlation: 0.2627497785857426
# Pearson correlation between estsim and model: 0.47829850191538553
# Spearman correlation between estsim and model: 0.5090790177625405
# Kendall tau correlation between estsim and model: 0.35915440788341796
# cbow_300_5_10_10_V
# Missing pairs: 3
# Pearson correlation: 0.18340035495055193
# Spearman correlation: 0.1637691471801753
# Kendall tau correlation: 0.11236769708214461
# Pearson correlation between estsim and model: 0.29838403193647484
# Spearman correlation between estsim and model: 0.26402429317544857
# Kendall tau correlation between estsim and model: 0.18678025541183418
# cbow_300_5_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.2879342612583708
# Spearman correlation: 0.3018900630905231
# Kendall tau correlation: 0.2223502771689175
# Pearson correlation between estsim and model: 0.3715035023630246
# Spearman correlation between estsim and model: 0.3321168984222682
# Kendall tau correlation between estsim and model: 0.2544748128227799
# cbow_300_5_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.38685371926515805
# Spearman correlation: 0.37479714908309736
# Kendall tau correlation: 0.2555160973308078
# Pearson correlation between estsim and model: 0.46512389712225305
# Spearman correlation between estsim and model: 0.4983046542374738
# Kendall tau correlation between estsim and model: 0.35163254821438
# cbow_300_5_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.17649156073515504
# Spearman correlation: 0.15901391129189082
# Kendall tau correlation: 0.10943052800232754
# Pearson correlation between estsim and model: 0.29166315257274106
# Spearman correlation between estsim and model: 0.25816908274482825
# Kendall tau correlation between estsim and model: 0.1816889941185571
# cbow_300_5_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.2998083557270393
# Spearman correlation: 0.30063514047918627
# Kendall tau correlation: 0.21479627956938266
# Pearson correlation between estsim and model: 0.3971972715214406
# Spearman correlation between estsim and model: 0.35978943803933955
# Kendall tau correlation between estsim and model: 0.267751759578751
# cbow_300_5_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.39899789014791115
# Spearman correlation: 0.389374345764295
# Kendall tau correlation: 0.2665271578311394
# Pearson correlation between estsim and model: 0.4738861488681596
# Spearman correlation between estsim and model: 0.5057675509914468
# Kendall tau correlation between estsim and model: 0.3565735657265669
# cbow_300_5_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.19949552014657676
# Spearman correlation: 0.17173833755037812
# Kendall tau correlation: 0.11740284407611673
# Pearson correlation between estsim and model: 0.3124410426628416
# Spearman correlation between estsim and model: 0.26579885998731395
# Kendall tau correlation between estsim and model: 0.187384303361884
# cbow_300_5_15_5_A
# Missing pairs: 0
# Pearson correlation: 0.29824879966250606
# Spearman correlation: 0.29239916236212615
# Kendall tau correlation: 0.20658541261336646
# Pearson correlation between estsim and model: 0.3941265248078651
# Spearman correlation between estsim and model: 0.3530072562574914
# Kendall tau correlation between estsim and model: 0.2653687178533203
# cbow_300_5_15_5_N
# Missing pairs: 16
# Pearson correlation: 0.4050456180612509
# Spearman correlation: 0.39163008071691296
# Kendall tau correlation: 0.2671287118888833
# Pearson correlation between estsim and model: 0.48036701826061423
# Spearman correlation between estsim and model: 0.5076275412875355
# Kendall tau correlation between estsim and model: 0.35744409086659823
# cbow_300_5_15_5_V
# Missing pairs: 3
# Pearson correlation: 0.190217318188467
# Spearman correlation: 0.17092028159266265
# Kendall tau correlation: 0.11631189556075612
# Pearson correlation between estsim and model: 0.31166328778842084
# Spearman correlation between estsim and model: 0.2749572301604728
# Kendall tau correlation between estsim and model: 0.19376995311955353
# cbow_300_5_2_20_A
# Missing pairs: 0
# Pearson correlation: 0.2866093210504286
# Spearman correlation: 0.2934259172259472
# Kendall tau correlation: 0.2124972368216981
# Pearson correlation between estsim and model: 0.382643886790566
# Spearman correlation between estsim and model: 0.335569886669741
# Kendall tau correlation between estsim and model: 0.25753872361261937
# cbow_300_5_2_20_N
# Missing pairs: 7
# Pearson correlation: 0.3913653856824442
# Spearman correlation: 0.3792510655162148
# Kendall tau correlation: 0.2577387030575681
# Pearson correlation between estsim and model: 0.4689559066662208
# Spearman correlation between estsim and model: 0.4997730270846608
# Kendall tau correlation between estsim and model: 0.3520256843207181
# cbow_300_5_2_20_V
# Missing pairs: 1
# Pearson correlation: 0.18281089306373974
# Spearman correlation: 0.1637222145406748
# Kendall tau correlation: 0.11136530731078015
# Pearson correlation between estsim and model: 0.2847196129982242
# Spearman correlation between estsim and model: 0.25368688580686166
# Kendall tau correlation between estsim and model: 0.17876865229279928
# cbow_300_5_5_20_A
# Missing pairs: 0
# Pearson correlation: 0.2943825965077936
# Spearman correlation: 0.30443939888488214
# Kendall tau correlation: 0.22202184249067686
# Pearson correlation between estsim and model: 0.3818358008803705
# Spearman correlation between estsim and model: 0.34169772496807316
# Kendall tau correlation between estsim and model: 0.2609430689346633
# cbow_300_5_5_20_N
# Missing pairs: 14
# Pearson correlation: 0.3918623386147396
# Spearman correlation: 0.38009810334914457
# Kendall tau correlation: 0.25884019106675693
# Pearson correlation between estsim and model: 0.4690924776136277
# Spearman correlation between estsim and model: 0.5020123321149419
# Kendall tau correlation between estsim and model: 0.3540982598660927
# cbow_300_5_5_20_V
# Missing pairs: 1
# Pearson correlation: 0.175365386837922
# Spearman correlation: 0.1590643460684521
# Kendall tau correlation: 0.10848126309629452
# Pearson correlation between estsim and model: 0.2762765147153693
# Spearman correlation between estsim and model: 0.24834399516274558
# Kendall tau correlation between estsim and model: 0.17529577158016968
# cbow_300_5_5_5_A
# Missing pairs: 0
# Pearson correlation: 0.30509402518588824
# Spearman correlation: 0.29413235967498647
# Kendall tau correlation: 0.2115119327869762
# Pearson correlation between estsim and model: 0.4002051111368168
# Spearman correlation between estsim and model: 0.3502837725693438
# Kendall tau correlation between estsim and model: 0.2626452415956852
# cbow_300_5_5_5_N
# Missing pairs: 14
# Pearson correlation: 0.3971109276189924
# Spearman correlation: 0.3855112381893218
# Kendall tau correlation: 0.26309918616594186
# Pearson correlation between estsim and model: 0.47107261796602296
# Spearman correlation between estsim and model: 0.5008565917933291
# Kendall tau correlation between estsim and model: 0.3524384617503484
# cbow_300_5_5_5_V
# Missing pairs: 1
# Pearson correlation: 0.18990567898462812
# Spearman correlation: 0.16327527263213354
# Kendall tau correlation: 0.11078849846788302
# Pearson correlation between estsim and model: 0.29808803813336454
# Spearman correlation between estsim and model: 0.25505705803427625
# Kendall tau correlation between estsim and model: 0.18080155807580198
# cbow_450_5_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.3311985226087203
# Spearman correlation: 0.3330086335786373
# Kendall tau correlation: 0.23745827236798722
# Pearson correlation between estsim and model: 0.42359271297863277
# Spearman correlation between estsim and model: 0.38962838513561926
# Kendall tau correlation between estsim and model: 0.2936247840262845
# cbow_450_5_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.4040006161173012
# Spearman correlation: 0.39780854113352937
# Kendall tau correlation: 0.2719099232558298
# Pearson correlation between estsim and model: 0.4785537921951276
# Spearman correlation between estsim and model: 0.5111743537086874
# Kendall tau correlation between estsim and model: 0.3610348728006774
# cbow_450_5_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.20267027832330584
# Spearman correlation: 0.17373663345826124
# Kendall tau correlation: 0.1198364984565366
# Pearson correlation between estsim and model: 0.31874759417532184
# Spearman correlation between estsim and model: 0.2727010361686503
# Kendall tau correlation between estsim and model: 0.19195780926940406
# cbow_750_5_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.2891663190763024
# Spearman correlation: 0.2912758749897408
# Kendall tau correlation: 0.2167668876388265
# Pearson correlation between estsim and model: 0.37104488282490644
# Spearman correlation between estsim and model: 0.31118674942926355
# Kendall tau correlation between estsim and model: 0.23745308621256048
# cbow_750_5_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.391337657454624
# Spearman correlation: 0.38444164772104344
# Kendall tau correlation: 0.2621265110102522
# Pearson correlation between estsim and model: 0.4726551788085116
# Spearman correlation between estsim and model: 0.5070252856077111
# Kendall tau correlation between estsim and model: 0.35761933448157346
# cbow_750_5_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.1675339079279282
# Spearman correlation: 0.1496434002064115
# Kendall tau correlation: 0.10212956486106795
# Pearson correlation between estsim and model: 0.2787811794609167
# Spearman correlation between estsim and model: 0.2454736196274374
# Kendall tau correlation between estsim and model: 0.17383637076790942
# skip_150_5_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.2721053620624486
# Spearman correlation: 0.294680839837284
# Kendall tau correlation: 0.2187374957082704
# Pearson correlation between estsim and model: 0.36187326223320465
# Spearman correlation between estsim and model: 0.33969932459949737
# Kendall tau correlation between estsim and model: 0.25856002720923255
# skip_150_5_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.3837098368177785
# Spearman correlation: 0.3688988798032723
# Kendall tau correlation: 0.25079437327406184
# Pearson correlation between estsim and model: 0.46833611391671076
# Spearman correlation between estsim and model: 0.4948586685411204
# Kendall tau correlation between estsim and model: 0.3475358210732076
# skip_150_5_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.18725393508116997
# Spearman correlation: 0.16950525044234063
# Kendall tau correlation: 0.11547270439509409
# Pearson correlation between estsim and model: 0.29317343761068787
# Spearman correlation between estsim and model: 0.2684839315155743
# Kendall tau correlation between estsim and model: 0.18841981413339798
# skip_300_10_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.22503602838391765
# Spearman correlation: 0.2595824972915387
# Kendall tau correlation: 0.20100202308327547
# Pearson correlation between estsim and model: 0.31042825255084305
# Spearman correlation between estsim and model: 0.2906058783767843
# Kendall tau correlation between estsim and model: 0.22009092507013675
# skip_300_10_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.3784632545724438
# Spearman correlation: 0.37552768664670094
# Kendall tau correlation: 0.25643211179781655
# Pearson correlation between estsim and model: 0.47278714761169416
# Spearman correlation between estsim and model: 0.5089949434342532
# Kendall tau correlation between estsim and model: 0.35953817623387907
# skip_300_10_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.1616619275199012
# Spearman correlation: 0.15085448863543158
# Kendall tau correlation: 0.10120645457883973
# Pearson correlation between estsim and model: 0.24681947904806
# Spearman correlation between estsim and model: 0.25739790589120654
# Kendall tau correlation between estsim and model: 0.17780582872537967
# skip_300_15_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.20034773491420604
# Spearman correlation: 0.246761225017671
# Kendall tau correlation: 0.1796537689976335
# Pearson correlation between estsim and model: 0.270361292075372
# Spearman correlation between estsim and model: 0.2593079221618541
# Kendall tau correlation between estsim and model: 0.1983031150090559
# skip_300_15_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.3708901015927436
# Spearman correlation: 0.36661084637198027
# Kendall tau correlation: 0.24935896916081107
# Pearson correlation between estsim and model: 0.4641344076398624
# Spearman correlation between estsim and model: 0.49959166318814946
# Kendall tau correlation between estsim and model: 0.3519683455210335
# skip_300_15_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.11352434268610802
# Spearman correlation: 0.11169063092793166
# Kendall tau correlation: 0.0802266754372892
# Pearson correlation between estsim and model: 0.190817684223674
# Spearman correlation between estsim and model: 0.21107339829900756
# Kendall tau correlation between estsim and model: 0.14535982455127497
# skip_300_5_10_10_A
# Missing pairs: 0
# Pearson correlation: 0.26781799934083633
# Spearman correlation: 0.26627834311286724
# Kendall tau correlation: 0.19673237226614707
# Pearson correlation between estsim and model: 0.35656273004596767
# Spearman correlation between estsim and model: 0.3062747520631402
# Kendall tau correlation between estsim and model: 0.23370830635831225
# skip_300_5_10_10_N
# Missing pairs: 14
# Pearson correlation: 0.3847640923695623
# Spearman correlation: 0.38290348362732207
# Kendall tau correlation: 0.26143713929796725
# Pearson correlation between estsim and model: 0.4851710930409651
# Spearman correlation between estsim and model: 0.5217655305401097
# Kendall tau correlation between estsim and model: 0.36883496452379966
# skip_300_5_10_10_V
# Missing pairs: 3
# Pearson correlation: 0.20638931313457054
# Spearman correlation: 0.17827135984956372
# Kendall tau correlation: 0.12352893958544948
# Pearson correlation between estsim and model: 0.2988448506141814
# Spearman correlation between estsim and model: 0.27538094740569685
# Kendall tau correlation between estsim and model: 0.19627243748404566
# skip_300_5_10_20_A
# Missing pairs: 0
# Pearson correlation: 0.2722752112262648
# Spearman correlation: 0.2833996998591478
# Kendall tau correlation: 0.2059285432568852
# Pearson correlation between estsim and model: 0.36301083977646764
# Spearman correlation between estsim and model: 0.3255999910256292
# Kendall tau correlation between estsim and model: 0.25209177109734915
# skip_300_5_10_20_N
# Missing pairs: 14
# Pearson correlation: 0.3871913237160377
# Spearman correlation: 0.38643942311722634
# Kendall tau correlation: 0.2635619151235029
# Pearson correlation between estsim and model: 0.4861942308798597
# Spearman correlation between estsim and model: 0.5230261470856684
# Kendall tau correlation between estsim and model: 0.37000545799270607
# skip_300_5_10_20_V
# Missing pairs: 3
# Pearson correlation: 0.22510284424921828
# Spearman correlation: 0.20790703646856093
# Kendall tau correlation: 0.1444247996104338
# Pearson correlation between estsim and model: 0.3281116325573087
# Spearman correlation between estsim and model: 0.3138887605403316
# Kendall tau correlation between estsim and model: 0.22449010600780164
# skip_300_5_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.27994339929635487
# Spearman correlation: 0.28259672490154425
# Kendall tau correlation: 0.20297263115271935
# Pearson correlation between estsim and model: 0.3778075244358132
# Spearman correlation between estsim and model: 0.3403846167612878
# Kendall tau correlation between estsim and model: 0.2602621998702545
# skip_300_5_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.3909990797234143
# Spearman correlation: 0.3878635448982272
# Kendall tau correlation: 0.2644495992461712
# Pearson correlation between estsim and model: 0.48581287062715883
# Spearman correlation between estsim and model: 0.521185027639384
# Kendall tau correlation between estsim and model: 0.3683936309207694
# skip_300_5_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.18532704256424715
# Spearman correlation: 0.16243409356761873
# Kendall tau correlation: 0.11354256471407144
# Pearson correlation between estsim and model: 0.3028327877652254
# Spearman correlation between estsim and model: 0.2764623150978384
# Kendall tau correlation between estsim and model: 0.19532321927682453
# skip_300_5_15_5_A
# Missing pairs: 0
# Pearson correlation: 0.3004459784293024
# Spearman correlation: 0.30615504483254885
# Kendall tau correlation: 0.2239924505601207
# Pearson correlation between estsim and model: 0.389732534811775
# Spearman correlation between estsim and model: 0.35330790056072847
# Kendall tau correlation between estsim and model: 0.2636665451922984
# skip_300_5_15_5_N
# Missing pairs: 16
# Pearson correlation: 0.3909804469101122
# Spearman correlation: 0.38763668601981616
# Kendall tau correlation: 0.26432568238322873
# Pearson correlation between estsim and model: 0.4890685033271332
# Spearman correlation between estsim and model: 0.5232772173819092
# Kendall tau correlation between estsim and model: 0.36964641436072754
# skip_300_5_15_5_V
# Missing pairs: 3
# Pearson correlation: 0.19064189393140493
# Spearman correlation: 0.16502822213185467
# Kendall tau correlation: 0.11446567499629966
# Pearson correlation between estsim and model: 0.29431069106110047
# Spearman correlation between estsim and model: 0.2690280555557877
# Kendall tau correlation between estsim and model: 0.18919644721203346
# skip_300_5_5_5_A
# Missing pairs: 0
# Pearson correlation: 0.3004963690256398
# Spearman correlation: 0.30250874871359473
# Kendall tau correlation: 0.22005123442123298
# Pearson correlation between estsim and model: 0.3905236750763065
# Spearman correlation between estsim and model: 0.3503721973644135
# Kendall tau correlation between estsim and model: 0.2650282833211159
# skip_300_5_5_5_N
# Missing pairs: 14
# Pearson correlation: 0.38895599961751715
# Spearman correlation: 0.387404279965736
# Kendall tau correlation: 0.2640529744254045
# Pearson correlation between estsim and model: 0.48673561362676027
# Spearman correlation between estsim and model: 0.5204143607425117
# Kendall tau correlation between estsim and model: 0.36706963011167854
# skip_300_5_5_5_V
# Missing pairs: 1
# Pearson correlation: 0.1656629716238288
# Spearman correlation: 0.1488891909764884
# Kendall tau correlation: 0.10279557593059432
# Pearson correlation between estsim and model: 0.2786251432156073
# Spearman correlation between estsim and model: 0.2592997941049145
# Kendall tau correlation between estsim and model: 0.18198741978255353
# skip_450_5_10_5_A
# Missing pairs: 0
# Pearson correlation: 0.29450509273818964
# Spearman correlation: 0.2973749743944896
# Kendall tau correlation: 0.2167668876388265
# Pearson correlation between estsim and model: 0.3861283931050118
# Spearman correlation between estsim and model: 0.3410875938820921
# Kendall tau correlation between estsim and model: 0.25753872361261937
# skip_450_5_10_5_N
# Missing pairs: 14
# Pearson correlation: 0.39069944201972917
# Spearman correlation: 0.395701377771102
# Kendall tau correlation: 0.2695490612274568
# Pearson correlation between estsim and model: 0.4912853909237653
# Spearman correlation between estsim and model: 0.5308975844029218
# Kendall tau correlation between estsim and model: 0.3754549685692539
# skip_450_5_10_5_V
# Missing pairs: 3
# Pearson correlation: 0.17982122360611208
# Spearman correlation: 0.15703789484095668
# Kendall tau correlation: 0.1084234986035331
# Pearson correlation between estsim and model: 0.29386046994966464
# Spearman correlation between estsim and model: 0.26530977905338143
# Kendall tau correlation between estsim and model: 0.18591732976890585
